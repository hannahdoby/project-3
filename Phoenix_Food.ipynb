# %%
# Impot dependencies
import requests
import json
import pprint
import pandas as pd
import numpy as np

# %%
# Loop through to get restaurants from NYC
locations = ['Phoenix']
for location in locations:
    category= 'food'
    url = 'https://api.yelp.com/v3/businesses/search?location='+location+'&categories='+category+'&sort_by=best_match&limit=40'
    headers = {"accept": "application/json","Authorization": "Bearer CHjD6kmFOME90In-E5XCPX4j-bRFI8XTrhXpC4mSkiUPM5rEYHz0Ny_NDkuBFvliTm2yaGMLW-h4NUsjLtyakj8wgZMT48_vJQP8_RccUQ3jgR2mt6pUW9QwYmQTZXYx" }
    response = requests.get(url, headers=headers)
    locals()[location+'_'+category] = json.loads(response.text)
    pprint.pprint(response.text)
# Out:
# ('{"businesses": [{"id": "LelAlfuj5oVRF9CQdWLsNQ", "alias": '
#  '"the-henry-phoenix", "name": "The Henry", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/3OHRbGTV2NJq7InmzoiW-Q/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/the-henry-phoenix?adjust_creative=y8ZvM3kGg52X--syYYcgfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y8ZvM3kGg52X--syYYcgfg", '
#  '"review_count": 2124, "categories": [{"alias": "newamerican", "title": '
#  '"American (New)"}, {"alias": "breakfast_brunch", "title": "Breakfast & '
#  'Brunch"}, {"alias": "coffee", "title": "Coffee & Tea"}], "rating": 4.0, '
#  '"coordinates": {"latitude": 33.5088410019446, "longitude": '
#  '-111.984304687697}, "transactions": ["delivery"], "price": "$$", "location": '
#  '{"address1": "4455 E Camelback Rd", "address2": "", "address3": "", "city": '
#  '"Phoenix", "zip_code": "85018", "country": "US", "state": "AZ", '
# ...

# %%
pprint.pprint(Phoenix_food)
# Out:
# {'businesses': [{'alias': 'the-henry-phoenix',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 33.5088410019446,
#                                  'longitude': -111.984304687697},
#                  'display_phone': '(602) 429-8020',
#                  'distance': 7664.725437695629,
#                  'id': 'LelAlfuj5oVRF9CQdWLsNQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3OHRbGTV2NJq7InmzoiW-Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4455 E Camelback Rd',
#                               'address2': '',
#                               'address3': '',
# ...

# %%
# export to json
with open('Phoenix_food.json','w') as outfile:
    json.dump(Phoenix_food, outfile)

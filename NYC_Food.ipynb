# %%
# Impot dependencies
import requests
import json
import pprint
import pandas as pd
import numpy as np

# %%
# Loop through to get restaurants from NYC
locations = ['NYC']
for location in locations:
    category= 'food'
    url = 'https://api.yelp.com/v3/businesses/search?location='+location+'&categories='+category+'&sort_by=best_match&limit=40'
    headers = {"accept": "application/json","Authorization": "Bearer CHjD6kmFOME90In-E5XCPX4j-bRFI8XTrhXpC4mSkiUPM5rEYHz0Ny_NDkuBFvliTm2yaGMLW-h4NUsjLtyakj8wgZMT48_vJQP8_RccUQ3jgR2mt6pUW9QwYmQTZXYx" }
    response = requests.get(url, headers=headers)
    locals()[location+'_'+category] = json.loads(response.text)
    pprint.pprint(response.text)
# Out:
# ('{"businesses": [{"id": "MphfKkYFEe0BDQ6hZ0A5fA", "alias": '
#  '"gelso-and-grand-new-york", "name": "Gelso & Grand", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/ZV0bgSfrkjlb1rewpItqCA/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/gelso-and-grand-new-york?adjust_creative=y8ZvM3kGg52X--syYYcgfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y8ZvM3kGg52X--syYYcgfg", '
#  '"review_count": 1447, "categories": [{"alias": "italian", "title": '
#  '"Italian"}, {"alias": "pastashops", "title": "Pasta Shops"}, {"alias": '
#  '"pizza", "title": "Pizza"}], "rating": 4.5, "coordinates": {"latitude": '
#  '40.71958, "longitude": -73.99734}, "transactions": ["pickup", "delivery"], '
#  '"price": "$$", "location": {"address1": "186 Grand St", "address2": "", '
#  '"address3": "", "city": "New York", "zip_code": "10013", "country": "US", '
#  '"state": "NY", "display_address": ["186 Grand St", "New York, NY 10013"]}, '
# ...

# %%
pprint.pprint(NYC_food['businesses'][8])
# Out:
# {'alias': '5ive-spice-brooklyn-3',
#  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                 {'alias': 'tacos', 'title': 'Tacos'}],
#  'coordinates': {'latitude': 40.681442, 'longitude': -73.977241},
#  'display_phone': '(718) 857-3483',
#  'distance': 3040.209344004305,
#  'id': 'SSDOkx5enfRH3nsniS_2jA',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/c94MoMzHNM7hBawXPgTfsQ/o.jpg',
#  'is_closed': False,
#  'location': {'address1': '52 5th Ave',
#               'address2': '',
#               'address3': '',
#               'city': 'Brooklyn',
#               'country': 'US',
#               'display_address': ['52 5th Ave', 'Brooklyn, NY 11217'],
#               'state': 'NY',
#               'zip_code': '11217'},
#  'name': '5ive Spice',
#  'phone': '+17188573483',
#  'price': '$$',
#  'rating': 4.5,
#  'review_count': 955,
#  'transactions': ['pickup', 'delivery'],
# ...

# %%
nyc_foods = NYC_food['businesses']
nyc_foods[4]['categories'][1]['title']
# Out:
# 'Breakfast & Brunch'

# %%
# Create lists of NYC_food Name, latitude, longitude, rating, and review
nyc_food_name = []
nyc_food_category = []
nyc_food_lat = []
nyc_food_lon = []
nyc_food_rating = []
nyc_food_review_count = []
for i in range(len(nyc_foods)):
    nyc_food_name.append(nyc_foods[i]['name'])
    nyc_food_category.append(nyc_foods[i]['categories'])
    nyc_food_lat.append(nyc_foods[i]['coordinates']['latitude'])
    nyc_food_lon.append(nyc_foods[i]['coordinates']['longitude'])
    nyc_food_rating.append(nyc_foods[i]['rating'])
    nyc_food_review_count.append(nyc_foods[i]['review_count'])   
print(len(nyc_food_name))
# Out:
# 40

# %%
# Set up DataFrame for NYC foods
nyc_food_df = pd.DataFrame({"NYC Restaurant Name": nyc_food_name,
                             "NYC Restaurant Category": nyc_food_category,
                             "NYC Restaurant Rating" : nyc_food_rating,
                             "NYC Restaurant Review Count" : nyc_food_review_count})
nyc_food_df
# Out:
#               NYC Restaurant Name  \
# 0                   Gelso & Grand
# 1             Best Bagel & Coffee
# 2       Ayza Wine & Chocolate Bar
# 3   Clinton Street Baking Company
# 4             Junior's Restaurant
# 5             Eataly NYC Flatiron
# 6        Levain Bakery - New York
# 7                Keens Steakhouse
# 8                      5ive Spice
# 9                       Scarpetta
# 10                  Lobster Place
# 11                   Bibble & Sip
# 12             Hometown Bar-B-Que
# 13                  Krupa Grocery
# 14                      MONO+MONO
# 15                   Saigon Shack
# 16                      Tofu Tofu
# 17                    Taiyaki NYC
# 18                         Barano
# 19                           JoJu
# 20               Russ & Daughters
# 21                      Bar Primi
# 22                   Sweet Moment
# 23                           Uluh
# 24                          Vic's
# 25                   Grace Street
# ...

# %%
# export to json
with open('NYC_food.json','w') as outfile:
    json.dump(NYC_food, outfile)

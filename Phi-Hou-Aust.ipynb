# %%
import json
import pprint
import requests

url = "https://api.yelp.com/v3/businesses/search?location="
headers = {
    "accept": "application/json",
    "Authorization": "Bearer kYCbl77E-qMIxVjuJLWY4p_8UFapl1_LehuxNfNpWBU68an-kZr6rrgr90Pj8Flmlsyx0IiUwaJStbmgDlZvUQ19hsaVoBcTbrYBaF30FnxtmgX69qwpXiqqgloTZXYx"
}

locations= ["Philadelphia","Houston", "Austin"]
interests = ["hotels","food"]

data= {}

# Loop through the locations and interests to pull the data from the Yelp API
for location in locations:
    i = 0
    term = interests[i]
    response = requests.get(f"{url}{location}&term={term}&sort_by=best_match&limit=40", headers=headers)
    locals()[f"{location}_{term}"] = json.loads(response.text)
    i += 1
    term = interests[i]
    response = requests.get(f"{url}{location}&term={term}&sort_by=best_match&limit=40", headers=headers)
    locals()[f"{location}_{term}"] = json.loads(response.text)

#Define locals variables
Philadelphia_food = locals()["Philadelphia_food"]
Philadelphia_hotels = locals()["Philadelphia_hotels"]
Houston_food = locals()["Houston_food"]
Houston_hotels = locals()["Houston_hotels"]
Austin_food = locals()["Austin_food"]
Austin_hotels = locals()["Austin_hotels"]


#Pretty print varables
pprint.pprint(Philadelphia_food)
pprint.pprint(Philadelphia_hotels)
pprint.pprint(Houston_food)
pprint.pprint(Houston_hotels)
pprint.pprint(Austin_food)
pprint.pprint(Austin_hotels)
# Out:
# {'businesses': [{'alias': 'chubby-cattle-philadelphia-5',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'hotpot', 'title': 'Hot Pot'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 39.95498, 'longitude': -75.15622},
#                  'display_phone': '(866) 622-8853',
#                  'distance': 6186.810698368317,
#                  'id': 'iksVwRfpWymIUUFqw0tXpw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gFMPEENrXHR6KC9iTmiPqA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '146 N 10th St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
# ...

# %%
import os

#Make file path for JSON Folder 
folder_name = 'JSON'

# Construct the file path for Ph FOOD
json_file_path = os.path.join(folder_name, 'Philadelphia_food.json')

# Export to JSON
with open(json_file_path, 'w') as outfile:
    json.dump(Philadelphia_food, outfile)


# Construct the file path for Phi HOTELS
json_file_path = os.path.join(folder_name, 'Philadelphia_hotels.json')

# Export to JSON
with open(json_file_path, 'w') as outfile:
    json.dump(Philadelphia_hotels, outfile)


# Construct the file path SD FOOD
json_file_path = os.path.join(folder_name, 'Houston_food.json')

# Export to JSON
with open(json_file_path, 'w') as outfile:
    json.dump(Houston_food, outfile)

# Construct the file path SD HOTELS
json_file_path = os.path.join(folder_name, 'Houston_hotels.json')

# Export to JSON
with open(json_file_path, 'w') as outfile:
    json.dump(Houston_hotels, outfile)

# Construct the file path DALLAS FOOD
json_file_path = os.path.join(folder_name, 'Austin_food.json')

# Export to JSON
with open(json_file_path, 'w') as outfile:
    json.dump(Austin_food, outfile)

# Construct the file path DALLAS HOTELS
json_file_path = os.path.join(folder_name, 'Austin_hotels.json')

# Export to JSON
with open(json_file_path, 'w') as outfile:
    json.dump(Austin_hotels, outfile)

# %%
# Load JSON data from the file
with open('JSON/Philadelphia_food.json', 'r') as json_file:
    data = json.load(json_file)

# Print the loaded data to check its structure
print(json.dumps(data, indent=4))

# Attempt to access the 'businesses' key
try:
    businesses = data['businesses']
    for business in businesses:
        print(business['name'])
except KeyError:
    print("The 'businesses' key does not exist in the loaded data.")
# Out:
# {
#     "businesses": [
#         {
#             "id": "iksVwRfpWymIUUFqw0tXpw",
#             "alias": "chubby-cattle-philadelphia-5",
#             "name": "Chubby Cattle",
#             "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/gFMPEENrXHR6KC9iTmiPqA/o.jpg",
#             "is_closed": false,
#             "url": "https://www.yelp.com/biz/chubby-cattle-philadelphia-5?adjust_creative=XXt1Nge7yivmjq1WyN0Lzw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=XXt1Nge7yivmjq1WyN0Lzw",
#             "review_count": 1489,
#             "categories": [
#                 {
#                     "alias": "chinese",
#                     "title": "Chinese"
#                 },
#                 {
#                     "alias": "hotpot",
#                     "title": "Hot Pot"
#                 },
#                 {
#                     "alias": "asianfusion",
#                     "title": "Asian Fusion"
#                 }
#             ],
# ...

# %%
import csv


#Define extracted data     
extracted_data_Ph_food = []
for business in data['businesses']:
    name = business['name']
    categories = ', '.join([category['title'] for category in business['categories']])
    review = business['rating']
    review_count = business['review_count']
    
    # Append the extracted data as a dictionary
    extracted_data_Ph_food.append({
        'Name': name,
        'Category': categories,
        'Review': review,
        'Review Count': review_count
    })


# Define the CSV filename
Ph_Food_csv_filename = 'extracted_data_Ph_food.csv'

# absolute path to the current directory
current_directory = os.getcwd()

# Define the CSV filename and folder
folder_path = os.path.join(current_directory, 'CSV')
os.makedirs(folder_path, exist_ok=True)
Ph_Food_csv_filename = os.path.join(folder_path, 'extracted_data_Ph_food.csv')

# Write the extracted data to a CSV file
with open(Ph_Food_csv_filename, 'w', newline='') as csv_file:
    fieldnames = ['Name', 'Category', 'Review', 'Review Count']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write the header
    csv_writer.writeheader()

    # Write the extracted data
    csv_writer.writerows(extracted_data_Ph_food)

# %%
# Specify the folder name
folder_name = 'JSON'

# Construct the file path
json_file_path = os.path.join(folder_name, 'Philadelphia_hotels.json')

# Load JSON data from the file
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)


extracted_data_Ph_hotels = []
for business in data['businesses']:
    name = business['name']
    categories = ', '.join([category['title'] for category in business['categories']])
    review = business['rating']
    review_count = business['review_count']
    
    # Append the extracted data as a dictionary
    extracted_data_Ph_hotels.append({
        'Name': name,
        'Category': categories,
        'Review': review,
        'Review Count': review_count
    })

# Define the CSV filename
Ph_hotels_csv_filename = 'extracted_data_Ph_hotels.csv'

os.makedirs(folder_path, exist_ok=True)
Ph_hotels_csv_filename = os.path.join(folder_path, 'extracted_data_Ph_hotels.csv')

# Write the extracted data to a CSV file
with open(Ph_hotels_csv_filename, 'w', newline='') as csv_file:
    fieldnames = ['Name', 'Category', 'Review', 'Review Count']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write the header
    csv_writer.writeheader()

    # Write the extracted data
    csv_writer.writerows(extracted_data_Ph_hotels)

# %%
# Specify the folder name
folder_name = 'JSON'

# Construct the file path
json_file_path = os.path.join(folder_name, 'Houston_food.json')

# Load JSON data from the file
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)


extracted_data_Hou_food = []
for business in data['businesses']:
    name = business['name']
    categories = ', '.join([category['title'] for category in business['categories']])
    review = business['rating']
    review_count = business['review_count']
    
    # Append the extracted data as a dictionary
    extracted_data_Hou_food.append({
        'Name': name,
        'Category': categories,
        'Review': review,
        'Review Count': review_count
    })

# Define the CSV filename
Hou_Food_csv_filename = 'extracted_data_Hou_food.csv'

os.makedirs(folder_path, exist_ok=True)
Hou_Food_csv_filename = os.path.join(folder_path, 'extracted_data_Hou_food.csv')

# Write the extracted data to a CSV file
with open(Hou_Food_csv_filename, 'w', newline='') as csv_file:
    fieldnames = ['Name', 'Category', 'Review', 'Review Count']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write the header
    csv_writer.writeheader()

    # Write the extracted data
    csv_writer.writerows(extracted_data_Hou_food)

# %%
# Specify the folder name
folder_name = 'JSON'

# Construct the file path
json_file_path = os.path.join(folder_name, 'Houston_hotels.json')

# Load JSON data from the file
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)

extracted_data_Hou_hotels = []
for business in data['businesses']:
    name = business['name']
    categories = ', '.join([category['title'] for category in business['categories']])
    review = business['rating']
    review_count = business['review_count']
    
    # Append the extracted data as a dictionary
    extracted_data_Hou_hotels.append({
        'Name': name,
        'Category': categories,
        'Review': review,
        'Review Count': review_count
    })

# Define the CSV filename
Hou_hotels_csv_filename = 'extracted_data_Hou_hotels.csv'

os.makedirs(folder_path, exist_ok=True)
Hou_hotels_csv_filename = os.path.join(folder_path, 'extracted_data_Hou_hotels.csv')

# Write the extracted data to a CSV file
with open(Hou_hotels_csv_filename, 'w', newline='') as csv_file:
    fieldnames = ['Name', 'Category', 'Review', 'Review Count']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write the header
    csv_writer.writeheader()

    # Write the extracted data
    csv_writer.writerows(extracted_data_Hou_hotels)

# %%
# Specify the folder name
folder_name = 'JSON'

# Construct the file path
json_file_path = os.path.join(folder_name, 'Austin_food.json')

# Load JSON data from the file
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)


extracted_data_Aus_food = []
for business in data['businesses']:
    name = business['name']
    categories = ', '.join([category['title'] for category in business['categories']])
    review = business['rating']
    review_count = business['review_count']
    
    # Append the extracted data as a dictionary
    extracted_data_Aus_food.append({
        'Name': name,
        'Category': categories,
        'Review': review,
        'Review Count': review_count
    })

# Define the CSV filename
Aus_Food_csv_filename = 'extracted_data_Aus_food.csv'

os.makedirs(folder_path, exist_ok=True)
Aus_Food_csv_filename = os.path.join(folder_path, 'extracted_data_Aus_food.csv')

# Write the extracted data to a CSV file
with open(Aus_Food_csv_filename, 'w', newline='') as csv_file:
    fieldnames = ['Name', 'Category', 'Review', 'Review Count']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write the header
    csv_writer.writeheader()

    # Write the extracted data
    csv_writer.writerows(extracted_data_Aus_food)

# %%
# Specify the folder name
folder_name = 'JSON'

# Construct the file path
json_file_path = os.path.join(folder_name, 'Austin_hotels.json')

# Load JSON data from the file
with open(json_file_path, 'r') as json_file:
    data = json.load(json_file)


extracted_data_Aus_hotels = []
for business in data['businesses']:
    name = business['name']
    categories = ', '.join([category['title'] for category in business['categories']])
    review = business['rating']
    review_count = business['review_count']
    
    # Append the extracted data as a dictionary
    extracted_data_Aus_hotels.append({
        'Name': name,
        'Category': categories,
        'Review': review,
        'Review Count': review_count
    })

# Define the CSV filename
Aus_hotels_csv_filename = 'extracted_data_Aus_hotels.csv'

# Define the CSV filename and folder
os.makedirs(folder_path, exist_ok=True)
Aus_hotels_csv_filename = os.path.join(folder_path, 'extracted_data_Aus_hotels.csv')

# Write the extracted data to a CSV file
with open(Aus_hotels_csv_filename, 'w', newline='') as csv_file:
    fieldnames = ['Name', 'Category', 'Review', 'Review Count']
    csv_writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    # Write the header
    csv_writer.writeheader()

    # Write the extracted data
    csv_writer.writerows(extracted_data_Aus_hotels)

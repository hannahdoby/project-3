# %%
#San Antonio
import json
import pprint
import requests

url = "https://api.yelp.com/v3/businesses/search?location=San%20Antonio&categories=hoteltravel&categories=active&categories=arts&categories=food&price=1&price=2&price=3&price=4&sort_by=rating&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer iYZnRBxpQmvIqH_Fc2NYor7h1BWUjfFLBk8-uj__-Hhkb8CZfTbmh3cNx4tNW17fxAhu4EFlQZkckYGMd5xPNm-4uTUD-HJ-FBRjupJTYYVEU9hnz4m9jA1fJ2ITZXYx"
}

response = requests.get(url, headers=headers)
SanAntonio = json.loads(response.text)
pprint.pprint(response.text)
# Out:
# ('{"businesses": [{"id": "yTR4donAIHH1ecwsbTDRww", "alias": '
#  '"irun-texas-san-antonio-2", "name": "iRun Texas", "image_url": '
#  '"https://s3-media4.fl.yelpcdn.com/bphoto/4aKSCaBtCo9d4BMGOJpm2Q/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/irun-texas-san-antonio-2?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", '
#  '"review_count": 8, "categories": [{"alias": "sportswear", "title": "Sports '
#  'Wear"}, {"alias": "shoes", "title": "Shoe Stores"}, {"alias": "fitness", '
#  '"title": "Fitness & Instruction"}], "rating": 5.0, "coordinates": '
#  '{"latitude": 29.648716, "longitude": -98.6244469508529}, "transactions": [], '
#  '"price": "$$", "location": {"address1": "22211 Interstate 10 W", "address2": '
#  '"Ste 107", "address3": "", "city": "San Antonio", "zip_code": "78257", '
#  '"country": "US", "state": "TX", "display_address": ["22211 Interstate 10 W", '
# ...

# %%
# San Antonio Data pull

# JSON data as a list of strings
json_data_list = [
    '{"businesses": [{"id": "yTR4donAIHH1ecwsbTDRww", "alias": "irun-texas-san-antonio-2", "name": "iRun Texas", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/4aKSCaBtCo9d4BMGOJpm2Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/irun-texas-san-antonio-2?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 8, "categories": [{"alias": "sportswear", "title": "Sports Wear"}, {"alias": "shoes", "title": "Shoe Stores"}, {"alias": "fitness", "title": "Fitness & Instruction"}], "rating": 5.0, "coordinates": {"latitude": 29.648716, "longitude": -98.6244469508529}, "transactions": [], "price": "$$", "location": {"address1": "22211 Interstate 10 W", "address2": "Ste 107", "address3": "", "city": "San Antonio", "zip_code": "78257", "country": "US", "state": "TX", "display_address": ["22211 Interstate 10 W", "Ste 107", "San Antonio, TX 78257"]}, "phone": "+12106987869", "display_phone": "(210) 698-7869", "distance": 20187.816428795875}]}',
    '{"businesses": [{"id": "6nCLm0oR2xKyoo4s7cp1mg", "alias": "cost-plus-nutrition-helotes", "name": "Cost Plus Nutrition", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/o9fZoWX1qcfZ9CmXI-GbPw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cost-plus-nutrition-helotes?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 6, "categories": [{"alias": "healthmarkets", "title": "Health Markets"}, {"alias": "vitaminssupplements", "title": "Vitamins & Supplements"}, {"alias": "nutritionists", "title": "Nutritionists"}], "rating": 5.0, "coordinates": {"latitude": 29.55642, "longitude": -98.66844}, "transactions": [], "price": "$$", "location": {"address1": "11838 Bandera Rd", "address2": null, "address3": null, "city": "Helotes", "zip_code": "78023", "country": "US", "state": "TX", "display_address": ["11838 Bandera Rd", "Helotes, TX 78023"]}, "phone": "+12105612906", "display_phone": "(210) 561-2906", "distance": 22689.05224083643}]}',
    '{"businesses": [{"id": "U0F_h22zby5JWQRghg6p4Q", "alias": "twirl-cotton-candy-san-antonio", "name": "Twirl Cotton Candy", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/Pr3IhmdAXQ6uzCUfD14mbQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/twirl-cotton-candy-san-antonio?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 13, "categories": [{"alias": "cottoncandy", "title": "Cotton Candy"}], "rating": 5.0, "coordinates": {"latitude": 29.424919, "longitude": -98.489785}, "transactions": [], "location": {"address1": "6565 Babcock Rd", "address2": "Ste 5", "address3": "", "city": "San Antonio", "zip_code": "78249", "country": "US", "state": "TX", "display_address": ["6565 Babcock Rd", "Ste 5", "San Antonio, TX 78249"]}, "phone": "+12106909292", "display_phone": "(210) 690-9292", "distance": 11856.704171908952}]}'
]

# Function to extract business info from JSON data
def extract_business_info(json_data):
    try:
        SanAntonio = json.loads(json_data)
        SANbusinesses = SanAntonio.get("businesses", [])

        results = []

        for business in SANbusinesses:
            name = business.get("name", "N/A")
            categories = [cat["title"] for cat in business.get("categories", [])]
            rating = business.get("rating", "N/A")
            review_count = business.get("review_count", "N/A")

            business_info = {
                "Name": name,
                "Category": ", ".join(categories),
                "Rating": rating,
                "Review Count": review_count,
            }

            results.append(business_info)

        return results
    except json.JSONDecodeError:
        return []

# Process each JSON data string in the list
for json_data in json_data_list:
    business_info_list = extract_business_info(json_data)
    for business_info in business_info_list:
        print("Name:", business_info["Name"])
        print("Category:", business_info["Category"])
        print("Rating:", business_info["Rating"])
        print("Review Count:", business_info["Review Count"])
        print("-" * 50)
# Out:
# Name: iRun Texas
# Category: Sports Wear, Shoe Stores, Fitness & Instruction
# Rating: 5.0
# Review Count: 8
# --------------------------------------------------
# Name: Cost Plus Nutrition
# Category: Health Markets, Vitamins & Supplements, Nutritionists
# Rating: 5.0
# Review Count: 6
# --------------------------------------------------
# Name: Twirl Cotton Candy
# Category: Cotton Candy
# Rating: 5.0
# Review Count: 13
# --------------------------------------------------

# %%
#San Diego

url = "https://api.yelp.com/v3/businesses/search?location=San%20diego&categories=hoteltravel&categories=active&categories=arts&categories=food&price=1&price=2&price=3&price=4&sort_by=rating&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer iYZnRBxpQmvIqH_Fc2NYor7h1BWUjfFLBk8-uj__-Hhkb8CZfTbmh3cNx4tNW17fxAhu4EFlQZkckYGMd5xPNm-4uTUD-HJ-FBRjupJTYYVEU9hnz4m9jA1fJ2ITZXYx"
}

response = requests.get(url, headers=headers)
SanDiego = json.loads(response.text)
pprint.pprint(response.text)
# Out:
# ('{"businesses": [{"id": "pfUGyldz6tJQCsgkCXIa6Q", "alias": '
#  '"na-pali-frozen-organics-san-diego", "name": "Na Pali Frozen Organics", '
#  '"image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/ND4Ucbvqus7U0_5l4-IY0w/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/na-pali-frozen-organics-san-diego?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", '
#  '"review_count": 6, "categories": [{"alias": "shavedice", "title": "Shaved '
#  'Ice"}], "rating": 5.0, "coordinates": {"latitude": 32.7211, "longitude": '
#  '-117.16431}, "transactions": [], "price": "$$", "location": {"address1": "", '
#  '"address2": null, "address3": "", "city": "San Diego", "zip_code": "92101", '
#  '"country": "US", "state": "CA", "display_address": ["San Diego, CA 92101"]}, '
#  '"phone": "+16194058291", "display_phone": "(619) 405-8291", "distance": '
# ...

# %%
# San Diego Data pull

# JSON data as a list of strings
json_data_list = [
    '{"businesses": [{"id": "pfUGyldz6tJQCsgkCXIa6Q", "alias": "na-pali-frozen-organics-san-diego", "name": "Na Pali Frozen Organics", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/ND4Ucbvqus7U0_5l4-IY0w/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/na-pali-frozen-organics-san-diego?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 6, "categories": [{"alias": "shavedice", "title": "Shaved Ice"}], "rating": 5.0, "coordinates": {"latitude": 32.7211, "longitude": -117.16431}, "transactions": [], "price": "$$", "location": {"address1": "", "address2": null, "address3": "", "city": "San Diego", "zip_code": "92101", "country": "US", "state": "CA", "display_address": ["San Diego, CA 92101"]}, "phone": "+16194058291", "display_phone": "(619) 405-8291", "distance": 7783.609135979237}]}',
    '{"businesses": [{"id": "TjM0hFnpAx--5oECY2UvDg", "alias": "le-caramel-el-cajon", "name": "Le Caramel", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/0mD3wGKR-x12ZB8Ps1VsMQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/le-caramel-el-cajon?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 11, "categories": [{"alias": "candy", "title": "Candy Stores"}], "rating": 5.0, "coordinates": {"latitude": 32.8119963, "longitude": -116.967292}, "transactions": [], "price": "$$", "location": {"address1": "1181 Pioneer Way", "address2": "", "address3": "", "city": "El Cajon", "zip_code": "92020", "country": "US", "state": "CA", "display_address": ["1181 Pioneer Way", "El Cajon, CA 92020"]}, "phone": "+16195620713", "display_phone": "(619) 562-0713", "distance": 17620.319948534237}]}',
    '{"businesses": [{"id": "ZCZp_L3TJ7LfI-SWBEwi7g", "alias": "the-wooden-spoon-bakery-and-cafe-san-diego-2", "name": "The Wooden Spoon Bakery & Cafe", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/YCk7s6irGzKTmc3JpwcaGg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/the-wooden-spoon-bakery-and-cafe-san-diego-2?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 10, "categories": [{"alias": "bakeries", "title": "Bakeries"}, {"alias": "coffee", "title": "Coffee & Tea"}, {"alias": "sandwiches", "title": "Sandwiches"}], "rating": 5.0, "coordinates": {"latitude": 32.9650748, "longitude": -117.2654648}, "transactions": [], "price": "$$", "location": {"address1": "897 S Coast Hwy 101", "address2": "Ste F104", "address3": "", "city": "Encinitas", "zip_code": "92024", "country": "US", "state": "CA", "display_address": ["897 S Coast Hwy 101", "Ste F104", "Encinitas, CA 92024"]}, "phone": "+17602022403", "display_phone": "(760) 202-2403", "distance": 30644.712011201617}]'
]


# Function to extract business info from JSON data
def extract_business_info(json_data):
    try:
        SanDiego = json.loads(json_data)
        SDbusinesses = SanDiego.get("businesses", [])

        results = []

        for business in SDbusinesses:
            name = business.get("name", "N/A")
            categories = [cat["title"] for cat in business.get("categories", [])]
            rating = business.get("rating", "N/A")
            review_count = business.get("review_count", "N/A")

            business_info = {
                "Name": name,
                "Category": ", ".join(categories),
                "Rating": rating,
                "Review Count": review_count,
            }

            results.append(business_info)

        return results
    except json.JSONDecodeError:
        return []

# Process each JSON data string in the list
for json_data in json_data_list:
    business_info_list = extract_business_info(json_data)
    for business_info in business_info_list:
        print("Name:", business_info["Name"])
        print("Category:", business_info["Category"])
        print("Rating:", business_info["Rating"])
        print("Review Count:", business_info["Review Count"])
        print("-" * 50)
# Out:
# Name: Na Pali Frozen Organics
# Category: Shaved Ice
# Rating: 5.0
# Review Count: 6
# --------------------------------------------------
# Name: Le Caramel
# Category: Candy Stores
# Rating: 5.0
# Review Count: 11
# --------------------------------------------------

# %%
#Dallas

url = "https://api.yelp.com/v3/businesses/search?location=Dallas&categories=hoteltravel&categories=active&categories=arts&categories=food&price=1&price=2&price=3&price=4&sort_by=rating&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer iYZnRBxpQmvIqH_Fc2NYor7h1BWUjfFLBk8-uj__-Hhkb8CZfTbmh3cNx4tNW17fxAhu4EFlQZkckYGMd5xPNm-4uTUD-HJ-FBRjupJTYYVEU9hnz4m9jA1fJ2ITZXYx"
}

response = requests.get(url, headers=headers)
Dallas = json.loads(response.text)
pprint.pprint(response.text)
# Out:
# ('{"businesses": [{"id": "eQsd8JsPq2_stdwTFyIWGw", "alias": '
#  '"quiktrip-mesquite-2", "name": "QuikTrip", "image_url": '
#  '"https://s3-media2.fl.yelpcdn.com/bphoto/L7gv-SLF3bTm0G_wAIB9Ag/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/quiktrip-mesquite-2?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", '
#  '"review_count": 5, "categories": [{"alias": "servicestations", "title": "Gas '
#  'Stations"}, {"alias": "convenience", "title": "Convenience Stores"}, '
#  '{"alias": "hotdogs", "title": "Fast Food"}], "rating": 5.0, "coordinates": '
#  '{"latitude": 32.824343, "longitude": -96.623629}, "transactions": [], '
#  '"price": "$", "location": {"address1": "4451 N Galloway Ave", "address2": '
#  '"", "address3": "", "city": "Mesquite", "zip_code": "75150", "country": '
#  '"US", "state": "TX", "display_address": ["4451 N Galloway Ave", "Mesquite, '
# ...

# %%
#Dalla Pullout request

# JSON data as a list of strings
json_data_list = [
    '{"businesses": [{"id": "eQsd8JsPq2_stdwTFyIWGw", "alias": "quiktrip-mesquite-2", "name": "QuikTrip", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/L7gv-SLF3bTm0G_wAIB9Ag/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/quiktrip-mesquite-2?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 5, "categories": [{"alias": "servicestations", "title": "Gas Stations"}, {"alias": "convenience", "title": "Convenience Stores"}, {"alias": "hotdogs", "title": "Fast Food"}], "rating": 5.0, "coordinates": {"latitude": 32.824343, "longitude": -96.623629}, "transactions": [], "price": "$", "location": {"address1": "4451 N Galloway Ave", "address2": "", "address3": "", "city": "Mesquite", "zip_code": "75150", "country": "US", "state": "TX", "display_address": ["4451 N Galloway Ave", "Mesquite, TX 75150"]}, "phone": "+19726862262", "display_phone": "(972) 686-2262", "distance": 16626.51284884689}]}',
    '{"businesses": [{"id": "WmObSM5DEw_kYYCqSRQcXQ", "alias": "dynamic-discs-carrollton-carrollton", "name": "Dynamic Discs Carrollton", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/0swfDU7TesPVoMJx5Iycww/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/dynamic-discs-carrollton-carrollton?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 8, "categories": [{"alias": "sportgoods", "title": "Sporting Goods"}, {"alias": "discgolf", "title": "Disc Golf"}], "rating": 5.0, "coordinates": {"latitude": 32.9753569789592, "longitude": -96.8875989869973}, "transactions": [], "price": "$$", "location": {"address1": "2150 N Josey Ln", "address2": "Ste 229", "address3": "", "city": "Carrollton", "zip_code": "75006", "country": "US", "state": "TX", "display_address": ["2150 N Josey Ln", "Ste 229", "Carrollton, TX 75006"]}, "phone": "+19722922003", "display_phone": "(972) 292-2003", "distance": 22265.99942588529}]}',
    '{"businesses": [{"id": "MVpBLNYmnmGGulDVC_Ys8g", "alias": "dirty-laundry-dallas", "name": "Dirty Laundry", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/qXdI2lMw_MiGyVhj3nHjAg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/dirty-laundry-dallas?adjust_creative=p8ZmzrMnEc-h1IE5NUGjPA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=p8ZmzrMnEc-h1IE5NUGjPA", "review_count": 13, "categories": [{"alias": "bars", "title": "Bars"}], "rating": 4.0, "coordinates": {"latitude": 32.784393, "longitude": -96.783664}, "transactions": [], "price": "$$", "location": {"address1": "1925 Greenville Ave", "address2": "", "address3": "", "city": "Dallas", "zip_code": "75206", "country": "US", "state": "TX", "display_address": ["1925 Greenville Ave", "Dallas, TX 75206"]}, "phone": "+12146325200", "display_phone": "(214) 632-5200", "distance": 3762.176994697327}]}'
]

# Function to extract business info from JSON data
def extract_business_info(json_data):
    try:
        Dallas = json.loads(json_data)
        Dbusinesses = Dallas.get("businesses", [])

        results = []

        for business in Dbusinesses:
            name = business.get("name", "N/A")
            categories = [cat["title"] for cat in business.get("categories", [])]
            rating = business.get("rating", "N/A")
            review_count = business.get("review_count", "N/A")

            business_info = {
                "Name": name,
                "Category": ", ".join(categories),
                "Rating": rating,
                "Review Count": review_count,
            }

            results.append(business_info)

        return results
    except json.JSONDecodeError:
        return []

# Process each JSON data string in the list
for json_data in json_data_list:
    business_info_list = extract_business_info(json_data)
    for business_info in business_info_list:
        print("Name:", business_info["Name"])
        print("Category:", business_info["Category"])
        print("Rating:", business_info["Rating"])
        print("Review Count:", business_info["Review Count"])
        print("-" * 50)
# Out:
# Name: QuikTrip
# Category: Gas Stations, Convenience Stores, Fast Food
# Rating: 5.0
# Review Count: 5
# --------------------------------------------------
# Name: Dynamic Discs Carrollton
# Category: Sporting Goods, Disc Golf
# Rating: 5.0
# Review Count: 8
# --------------------------------------------------
# Name: Dirty Laundry
# Category: Bars
# Rating: 4.0
# Review Count: 13
# --------------------------------------------------
